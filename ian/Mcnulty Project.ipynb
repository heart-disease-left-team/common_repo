# %%
import pymysql
import pandas as pd
import numpy as np

# %%
# Get all_data from MySQL on droplet
db = pymysql.connect(host="104.131.118.159",  #your cloud ip
                     user='root',
                     db='heart_disease')
cursor = db.cursor()

cursor.execute("SELECT * FROM all_data")
datalist = [row for row in cursor.fetchall()]
cursor.execute("SHOW COLUMNS FROM all_data")
columnlist = [column[0] for column in cursor.fetchall()]

cursor.close()
db.close()

# %%
# print columnlist

# %%
hd = pd.DataFrame(datalist, columns=columnlist)

# %%
print len(hd)
hd.head()
# Out:
# 899
#    id  ccf  age  sex  painloc  painexer  relrest pncaden  cp  trestbps  \
# 0   1    0   63    1      NaN       NaN      NaN    None   1       145
# 1   2    0   67    1      NaN       NaN      NaN    None   4       160
# 2   3    0   67    1      NaN       NaN      NaN    None   4       120
# 3   4    0   37    1      NaN       NaN      NaN    None   3       130
# 4   6    0   41    0      NaN       NaN      NaN    None   2       130
#
#      ...     rcadist  lvx1  lvx2  lvx3  lvx4  lvf  cathef  junk  name  \
# 0    ...           1     1     1     1     1    1     NaN   NaN  name
# 1    ...           1     1     1     1     1    1     NaN   NaN  name
# 2    ...           2     1     1     1     7    3     NaN   NaN  name
# 3    ...           1     1     1     1     1    1     NaN   NaN  name
# 4    ...           1     1     1     1     1    1     NaN   NaN  name
#
#     hospital
# 0  cleveland
# 1  cleveland
# 2  cleveland
# 3  cleveland
# 4  cleveland
#
# [5 rows x 77 columns]

# %%
hd.columns
# Out:
# Index([u'id', u'ccf', u'age', u'sex', u'painloc', u'painexer', u'relrest', u'pncaden', u'cp', u'trestbps', u'htn', u'chol', u'smoke', u'cigs', u'years', u'fbs', u'dm', u'famhist', u'restecg', u'ekgmo', u'ekgday', u'ekgyr', u'dig', u'prop', u'nitr', u'pro', u'diuretic', u'proto', u'thaldur', u'thaltime', u'met', u'thalach', u'thalrest', u'tpeakbps', u'tpeakbpd', u'dummy', u'trestbpd', u'exang', u'xhypo', u'oldpeak', u'slope', u'rldv5', u'rldv5e', u'ca', u'restckm', u'exerckm', u'restef', u'restwm', u'exeref', u'exerwm', u'thal', u'thalsev', u'thalpul', u'earlobe', u'cmo', u'cday', u'cyr', u'num', u'lmt', u'ladprox', u'laddist', u'diag', u'cxmain', u'ramus', u'om1', u'om2', u'rcaprox', u'rcadist', u'lvx1', u'lvx2', u'lvx3', u'lvx4', u'lvf', u'cathef', u'junk', u'name', u'hospital'], dtype='object')

# %%
hd.groupby('hospital').size()
# Out:
# hospital
# cleveland      282
# hungary        294
# long-beach     200
# switzerland    123
# dtype: int64

# %%
hd_good = hd[hd['hospital'] != 'cleveland']
print len(hd_good)
hd_good.head()
# Out:
# 617
#        id  ccf  age  sex  painloc  painexer  relrest pncaden  cp  trestbps  \
# 282  1254    0   40    1        1         0        0    None   2       140
# 283  1255    0   49    0        1         0        0    None   3       160
# 284  1256    0   37    1        1         0        0    None   2       130
# 285  1257    0   48    0        1         1        1    None   4       138
# 286  1258    0   54    1        1         0        1    None   3       150
#
#        ...     rcadist  lvx1  lvx2  lvx3  lvx4  lvf  cathef  junk  name  \
# 282    ...         NaN     1     1     1     1    1       0     0  name
# 283    ...         NaN     1     1     1     1    1       0     0  name
# 284    ...         NaN     1     1     1     1    1       0     0  name
# 285    ...         NaN     1     1     1     1    1       0     0  name
# 286    ...         NaN     1     1     1     1    1       0     0  name
#
#      hospital
# 282   hungary
# 283   hungary
# 284   hungary
# 285   hungary
# 286   hungary
#
# [5 rows x 77 columns]

# %%
for column in hd.columns:
    print hd.groupby(column).size()
    print '--------------------------------------'
# Out:
# id
# 1     2
# 2     2
# 3     2
# 4     2
# 5     1
# 6     2
# 7     2
# 8     2
# 9     2
# 10    2
# 11    2
# 12    2
# 13    2
# 14    2
# 15    2
# ...
# 4062    1
# 4063    1
# 4064    1
# 4065    1
# 4067    1
# 4068    1
# 4069    1
# 4070    1
# 4071    1
# 4072    1
# 4073    1
# 4074    1
# 5000    1
# 5001    1
# 5002    1
# Length: 714, dtype: int64
# --------------------------------------
# ccf
# 0      899
# dtype: int64
# --------------------------------------
# age
# 28      1
# 29      3
# 30      1
# 31      2
# 32      5
# 33      2
# 34      7
# 35     10
# 36      6
# 37     11
# 38     15
# 39     15
# 40     13
# 41     23
# 42     18
# 43     24
# 44     18
# 45     17
# 46     24
# 47     19
# 48     31
# 49     22
# 50     25
# 51     35
# 52     36
# 53     33
# 54     51
# 55     39
# 56     36
# 57     35
# 58     40
# 59     34
# 60     32
# 61     30
# 62     35
# 63     28
# 64     22
# 65     21
# 66     13
# 67     14
# 68      9
# 69     13
# 70      7
# 71      5
# 72      4
# 73      1
# 74      7
# 75      3
# 76      2
# 77      2
# dtype: int64
# --------------------------------------
# sex
# 0      188
# 1      711
# dtype: int64
# --------------------------------------
# painloc
# 0           49
# 1          568
# dtype: int64
# --------------------------------------
# painexer
# 0           251
# 1           366
# dtype: int64
# --------------------------------------
# relrest
# 0          201
# 1          412
# dtype: int64
# --------------------------------------
# Series([], dtype: int64)
# --------------------------------------
# cp
# 1      45
# 2     167
# 3     202
# 4     485
# dtype: int64
# --------------------------------------
# trestbps
# 0             1
# 80            1
# 92            1
# 94            2
# 95            6
# 96            1
# 98            1
# 100          15
# 101           1
# 102           3
# 104           3
# 105           9
# 106           3
# 108           7
# 110          58
# 112          14
# 113           1
# 114           1
# 115          19
# 116           2
# 117           1
# 118          10
# 120         128
# 122          11
# 123           1
# 124          11
# 125          28
# 126           7
# 127           1
# 128          16
# 129           1
# 130         112
# 132          11
# 134           9
# 135          18
# 136           8
# 138          14
# 140         100
# 142           9
# 144           5
# 145          16
# 146           3
# 148           1
# 150          56
# 152           6
# 154           3
# 155           8
# 156           2
# 158           4
# 160          50
# 165           2
# 170          13
# 172           2
# 174           1
# 178           3
# 180          12
# 185           1
# 190           2
# 192           1
# 200           4
# Length: 60, dtype: int64
# --------------------------------------
# htn
# 0      453
# 1      412
# dtype: int64
# --------------------------------------
# chol
# 0       172
# 85        1
# 100       2
# 117       1
# 126       1
# 129       1
# 132       1
# 139       1
# 141       1
# 142       1
# 147       2
# 149       2
# 153       1
# 156       1
# 160       5
# ...
# 393     1
# 394     2
# 404     1
# 407     1
# 409     1
# 412     1
# 417     1
# 458     1
# 466     1
# 468     1
# 491     1
# 518     1
# 529     1
# 564     1
# 603     1
# Length: 213, dtype: int64
# --------------------------------------
# smoke
# 0        111
# 1        119
# dtype: int64
# --------------------------------------
# cigs
# 0       153
# 1         1
# 2         6
# 3         2
# 4         2
# 5         2
# 7         1
# 8         1
# 9         1
# 10       21
# 15        9
# 20      136
# 25        6
# 28        1
# 30       35
# 35        2
# 40       63
# 45        1
# 50       12
# 60       17
# 65        1
# 70        1
# 75        1
# 80        3
# 99        1
# dtype: int64
# --------------------------------------
# years
# 0        153
# 1          3
# 2          1
# 3          2
# 4          3
# 5          6
# 6          3
# 7          3
# 8          2
# 10         9
# 14         2
# 15        15
# 17         1
# 18         4
# 19         1
# 20        53
# 21         1
# 22         2
# 23         3
# 24         3
# 25        26
# 27         1
# 28         1
# 29         2
# 30        58
# 31         1
# 32         3
# 33         1
# 34         2
# 35        17
# 36         1
# 37         2
# 38         2
# 40        51
# 41         2
# 42         1
# 45         6
# 47         3
# 48         1
# 50        13
# 54         2
# 60         1
# dtype: int64
# --------------------------------------
# fbs
# 0      674
# 1      135
# dtype: int64
# --------------------------------------
# dm
# 0      4
# 1     91
# dtype: int64
# --------------------------------------
# famhist
# 0          208
# 1          269
# dtype: int64
# --------------------------------------
# restecg
# 0          538
# 1          177
# 2          182
# dtype: int64
# --------------------------------------
# ekgmo
# 1        91
# 2        73
# 3        99
# 4        83
# 5        68
# 6        74
# 7        69
# 8        58
# 9        45
# 10       58
# 11       64
# 12       64
# dtype: int64
# --------------------------------------
# ekgday
# 1         29
# 2         36
# 3         35
# 4         24
# 5         24
# 6         25
# 7         28
# 8         25
# 9         30
# 10        24
# 11        23
# 12        28
# 13        29
# 14        27
# 15        24
# 16        41
# 17        23
# 18        31
# 19        28
# 20        35
# 21        29
# 22        30
# 23        23
# 24        24
# 25        29
# 26        26
# 27        24
# 28        31
# 29        28
# 30        22
# 31        10
# dtype: int64
# --------------------------------------
# ekgyr
# 81        68
# 82       100
# 83       140
# 84       171
# 85       183
# 86       143
# 87        41
# dtype: int64
# --------------------------------------
# dig
# 0      802
# 1       29
# dtype: int64
# --------------------------------------
# prop
# 0       618
# 1       214
# 22        1
# dtype: int64
# --------------------------------------
# nitr
# 0       612
# 1       222
# dtype: int64
# --------------------------------------
# pro
# 0      692
# 1      144
# dtype: int64
# --------------------------------------
# diuretic
# 0           725
# 1            92
# dtype: int64
# --------------------------------------
# proto
# 1        324
# 4          2
# 5         98
# 6          5
# 12        73
# 25        16
# 50        34
# 75        73
# 100       70
# 125       52
# 130        1
# 150       25
# 175       12
# 200        2
# dtype: int64
# --------------------------------------
# thaldur
# 1.0         1
# 1.5         4
# 1.7         1
# 1.8         1
# 2.0        11
# 2.3         1
# 2.5         1
# 3.0        22
# 3.1         2
# 3.2         1
# 3.4         2
# 3.5         2
# 3.6         2
# 3.8         1
# 4.0        39
# ...
# 12.4        1
# 12.5        2
# 13.0       32
# 13.3        1
# 14.0       19
# 14.4        1
# 15.0       11
# 16.0        6
# 16.5        1
# 17.0        5
# 18.0       15
# 19.0       12
# 20.0        6
# 21.0        1
# 24.0        1
# Length: 86, dtype: int64
# --------------------------------------
# thaltime
# 0.0         70
# 0.5          1
# 0.7          1
# 1.0          5
# 1.5          3
# 2.0          7
# 2.5          2
# 3.0         57
# 3.5          5
# 3.6          2
# 3.8          1
# 4.0         17
# 4.2          1
# 4.5          8
# 4.6          1
# ...
# 11.8         1
# 12.0        17
# 12.6         1
# 13.0         4
# 13.2         2
# 13.5         1
# 14.0         2
# 14.3         1
# 14.5         1
# 15.0         3
# 15.8         1
# 17.5         1
# 17.8         1
# 19.0         2
# 20.0         1
# Length: 64, dtype: int64
# --------------------------------------
# met
# 2.0       22
# 2.5        1
# 3.0       31
# 3.5        1
# 4.0       54
# 4.5        1
# 5.0      106
# 5.4        1
# 5.8        1
# 6.0      102
# 6.3        2
# 6.4        1
# 6.5        3
# 6.9        1
# 7.0      107
# 7.5        2
# 8.0       52
# 8.5        1
# 9.0       71
# 10.0      58
# 11.0      19
# 12.0      23
# 13.0      27
# 14.0      20
# 15.0       3
# 16.0       7
# 17.0       2
# 18.0       2
# 50.0      11
# 75.0       7
# 100.0     31
# 125.0      2
# 150.0     21
# 200.0      1
# dtype: int64
# --------------------------------------
# thalach
# 60         1
# 63         1
# 67         1
# 69         1
# 70         1
# 71         1
# 72         2
# 73         1
# 77         1
# 78         1
# 80         2
# 82         3
# 83         1
# 84         3
# 86         4
# ...
# 178         6
# 179         6
# 180        10
# 181         2
# 182         5
# 184         4
# 185         4
# 186         2
# 187         1
# 188         2
# 190         2
# 192         1
# 194         1
# 195         1
# 202         1
# Length: 119, dtype: int64
# --------------------------------------
# thalrest
# 37           1
# 39           1
# 40           1
# 43           1
# 44           1
# 46           2
# 47           1
# 49           4
# 50           4
# 51           1
# 52           9
# 53           4
# 54          11
# 55           5
# 56          20
# ...
# 102         5
# 103         1
# 105         3
# 108         1
# 109         1
# 110         6
# 112         2
# 115         2
# 116         1
# 119         1
# 120         3
# 124         1
# 125         3
# 134         1
# 139         1
# Length: 75, dtype: int64
# --------------------------------------
# tpeakbps
# 84           1
# 90           1
# 92           1
# 98           2
# 100          1
# 110          4
# 112          1
# 115          1
# 116          1
# 120          9
# 124          3
# 125          2
# 126          1
# 128          2
# 130         18
# ...
# 200         58
# 202          1
# 204          1
# 205          1
# 208          1
# 210         21
# 215          5
# 216          1
# 220         24
# 224          1
# 228          1
# 230         14
# 232          1
# 235          1
# 240          5
# Length: 74, dtype: int64
# --------------------------------------
# tpeakbpd
# 11            1
# 26            1
# 40            2
# 45            1
# 50            2
# 55            1
# 56            2
# 58            3
# 60           23
# 62            3
# 64            2
# 65            9
# 66            2
# 68           13
# 70           59
# 72            4
# 74            8
# 75           23
# 76            8
# 77            1
# 78           22
# 80          162
# 82           13
# 83            2
# 84           16
# 85           25
# 86            5
# 87            1
# 88            7
# 89            1
# 90          131
# 92            5
# 94            6
# 95           28
# 96            8
# 98           12
# 100         114
# 102           1
# 104          12
# 105          14
# 106           3
# 108           2
# 110          43
# 112           1
# 114           2
# 115           8
# 116           2
# 118           4
# 120          15
# 130           2
# 134           1
# Length: 51, dtype: int64
# --------------------------------------
# dummy
# 0          1
# 80         1
# 92         1
# 94         2
# 95         6
# 96         1
# 98         1
# 100       15
# 101        1
# 102        3
# 104        3
# 105        9
# 106        3
# 108        7
# 110       58
# 112       14
# 113        1
# 114        1
# 115       19
# 116        2
# 117        1
# 118       10
# 120      128
# 122       11
# 123        1
# 124       11
# 125       28
# 126        7
# 127        1
# 128       16
# 129        1
# 130      112
# 132       11
# 134        9
# 135       18
# 136        8
# 138       14
# 140      100
# 142        9
# 144        5
# 145       16
# 146        3
# 148        1
# 150       56
# 152        6
# 154        3
# 155        8
# 156        2
# 158        4
# 160       50
# 165        2
# 170       13
# 172        2
# 174        1
# 178        3
# 180       12
# 185        1
# 190        2
# 192        1
# 200        4
# Length: 60, dtype: int64
# --------------------------------------
# trestbpd
# 0             1
# 50            2
# 58            1
# 60           12
# 64            4
# 65            6
# 66            1
# 68            4
# 70           88
# 72            8
# 74            9
# 75           21
# 76            3
# 78           24
# 80          258
# 82           15
# 84           14
# 85           42
# 86           13
# 88           14
# 89            1
# 90          158
# 92            6
# 94           12
# 95           23
# 96            7
# 98           12
# 100          64
# 102           1
# 104           1
# 105           5
# 106           2
# 110           7
# 120           1
# dtype: int64
# --------------------------------------
# exang
# 0        514
# 1        330
# dtype: int64
# --------------------------------------
# xhypo
# 0        819
# 1         22
# dtype: int64
# --------------------------------------
# oldpeak
# -2.6         1
# -2.0         1
# -1.5         1
# -1.1         1
# -1.0         2
# -0.9         1
# -0.8         1
# -0.7         1
# -0.5         2
# -0.1         1
#  0.0       362
#  0.1         9
#  0.2        13
#  0.3         5
#  0.4         9
#  0.5        19
#  0.6        14
#  0.7         5
#  0.8        14
#  0.9         4
#  1.0        82
#  1.1         4
#  1.2        14
#  1.3         5
#  1.4        15
#  1.5        48
#  1.6        14
#  1.7         2
#  1.8        12
#  1.9         5
#  2.0        75
#  2.1         2
#  2.2         5
#  2.3         2
#  2.4         4
#  2.5        16
#  2.6         7
#  2.8         5
#  2.9         1
#  3.0        28
#  3.1         1
#  3.2         2
#  3.4         2
#  3.5         2
#  3.6         4
#  3.7         1
#  3.8         1
#  4.0         7
#  4.2         2
#  5.0         1
#  5.6         1
#  6.2         1
# Length: 52, dtype: int64
# --------------------------------------
# slope
# 0          1
# 1        196
# 2        334
# 3         60
# dtype: int64
# --------------------------------------
# rldv5
# 2         1
# 3         1
# 4         9
# 5         9
# 6        12
# 7        16
# 8        19
# 9        20
# 10       42
# 11       34
# 12       34
# 13       33
# 14       33
# 15       30
# 16       19
# 17       27
# 18       22
# 19       20
# 20       27
# 21       12
# 22       10
# 23        7
# 24       10
# 25       11
# 26        4
# 27        4
# 28        3
# 29        1
# 30        1
# 31        2
# 36        1
# dtype: int64
# --------------------------------------
# rldv5e
# 2          1
# 3          3
# 4          7
# 5          6
# 6         18
# 7         23
# 8         23
# 9         27
# 10        32
# 11        38
# 12        26
# 13        30
# 14        22
# 15        33
# 16        22
# ...
# 197       1
# 200       4
# 204       1
# 206       1
# 210       2
# 220       3
# 222       1
# 225       1
# 227       1
# 230       2
# 231       1
# 240       1
# 252       1
# 253       1
# 270       1
# Length: 141, dtype: int64
# --------------------------------------
# ca
# 0     171
# 1      63
# 2      37
# 3      19
# 9       1
# dtype: int64
# --------------------------------------
# Series([], dtype: int64)
# --------------------------------------
# exerckm
# 0          1
# dtype: int64
# --------------------------------------
# restef
# 0.22      1
# 0.30      1
# 0.33      1
# 0.36      1
# 0.38      1
# 0.39      1
# 0.40      1
# 0.41      1
# 0.45      2
# 0.48      1
# 0.50      1
# 0.52      1
# 0.56      1
# 0.58      1
# 0.59      2
# 0.60      2
# 0.61      1
# 0.62      1
# 0.64      2
# 0.67      1
# 0.70      1
# 0.72      1
# 0.76      1
# 0.80      1
# dtype: int64
# --------------------------------------
# restwm
# 0         13
# 1          6
# 2          8
# 3          3
# dtype: int64
# --------------------------------------
# exeref
# 0.5       1
# 0.6       1
# dtype: int64
# --------------------------------------
# exerwm
# 0         4
# 1         1
# dtype: int64
# --------------------------------------
# thal
# 1         4
# 2         1
# 3       189
# 4         1
# 5         3
# 6        42
# 7       182
# dtype: int64
# --------------------------------------
# thalsev
# 0          36
# 1          31
# 2          53
# 3          10
# dtype: int64
# --------------------------------------
# thalpul
# 0          31
# 1          13
# dtype: int64
# --------------------------------------
# earlobe
# 0          1
# dtype: int64
# --------------------------------------
# cmo
# 1      83
# 2      82
# 3      97
# 4      77
# 5      75
# 6      76
# 7      89
# 8      61
# 9      51
# 10     53
# 11     68
# 12     76
# dtype: int64
# --------------------------------------
# cday
# 1       28
# 2       24
# 3       30
# 4       30
# 5       32
# 6       31
# 7       22
# 8       27
# 9       22
# 10      42
# 11      24
# 12      33
# 13      24
# 14      29
# 15      31
# 16      36
# 17      28
# 18      21
# 19      23
# 20      52
# 21      29
# 22      28
# 23      21
# 24      16
# 25      32
# 26      36
# 27      19
# 28      32
# 29      26
# 30      53
# 31       9
# dtype: int64
# --------------------------------------
# cyr
# 1        1
# 16       1
# 26       1
# 80       1
# 81      66
# 82     102
# 83     164
# 84     170
# 85     179
# 86     158
# 87      47
# dtype: int64
# --------------------------------------
# num
# 0      404
# 1      191
# 2      130
# 3      132
# 4       42
# dtype: int64
# --------------------------------------
# lmt
# 0        1
# 1      580
# 2       42
# 162      1
# dtype: int64
# --------------------------------------
# ladprox
# 1          446
# 2          217
# dtype: int64
# --------------------------------------
# laddist
# 1          491
# 2          162
# dtype: int64
# --------------------------------------
# diag
# 1       272
# 2        69
# dtype: int64
# --------------------------------------
# cxmain
# 1         467
# 2         197
# dtype: int64
# --------------------------------------
# ramus
# 1        294
# 2         38
# dtype: int64
# --------------------------------------
# om1
# 1      517
# 2      111
# dtype: int64
# --------------------------------------
# om2
# 1      305
# 2       22
# dtype: int64
# --------------------------------------
# rcaprox
# 1          430
# 2          224
# dtype: int64
# --------------------------------------
# rcadist
# 1          521
# 2          108
# dtype: int64
# --------------------------------------
# lvx1
# 1       874
# 3         4
# 5         1
# 7         1
# dtype: int64
# --------------------------------------
# lvx2
# 1       871
# 2         3
# 3         2
# 4         1
# 5         1
# 7         1
# 10        1
# dtype: int64
# --------------------------------------
# lvx3
# 1       843
# 2         6
# 3         8
# 4         5
# 5        13
# 6         3
# 7         1
# 8         1
# dtype: int64
# --------------------------------------
# lvx4
# 1       769
# 2         3
# 3        16
# 4         5
# 5        21
# 6         4
# 7        50
# 8        12
# dtype: int64
# --------------------------------------
# lvf
# 0        2
# 1      759
# 2       94
# 3       19
# 4        8
# 5        1
# dtype: int64
# --------------------------------------
# cathef
# 0.00      282
# 0.22        2
# 0.32        1
# 0.40        5
# 0.41        2
# 0.42        1
# 0.43        2
# 0.44        1
# 0.45        1
# 0.47        1
# 0.48        3
# 0.50        4
# 0.52        2
# 0.53        3
# 0.54        4
# ...
# 67        10
# 68         8
# 69         3
# 70         9
# 71         4
# 72         3
# 73         3
# 74         1
# 75         4
# 76         4
# 77         2
# 79         1
# 80         1
# 83         1
# 86         1
# Length: 89, dtype: int64
# --------------------------------------
# junk
# 0.0     497
# 3.3       1
# 3.4       3
# 3.5       1
# 3.6       3
# 3.7       2
# 3.8       3
# 3.9       1
# 4.1       1
# 4.2       3
# 4.3       4
# 4.4       2
# 4.6       4
# 4.7       1
# 4.8       7
# 4.9       1
# 5.0       7
# 5.1       2
# 5.2       4
# 5.3       2
# 5.5       3
# 5.6       5
# 5.7       5
# 5.8       2
# 5.9       1
# 6.0       8
# 6.1       1
# 6.2       1
# 6.3       1
# 6.4       5
# 6.5       2
# 6.9       4
# 7.0       2
# 7.1       2
# 7.2       3
# 7.3       1
# 7.4       1
# 7.5       1
# 7.6       2
# 7.7       1
# 7.8       1
# 8.0       3
# 8.1       1
# 8.2       1
# 8.4       2
# 8.7       1
# 8.9       1
# 9.0       1
# 9.6       1
# 9.9       1
# 10.0      1
# 10.2      1
# 11.3      1
# Length: 53, dtype: int64
# --------------------------------------
# name
# name    899
# dtype: int64
# --------------------------------------
# hospital
# cleveland      282
# hungary        294
# long-beach     200
# switzerland    123
# dtype: int64
# --------------------------------------

# %%
hd_good['earlobe']
# Out:
# 282   NaN
# 283   NaN
# 284   NaN
# 285   NaN
# 286   NaN
# 287   NaN
# 288   NaN
# 289   NaN
# 290   NaN
# 291   NaN
# 292   NaN
# 293   NaN
# 294   NaN
# 295   NaN
# 296   NaN
# ...
# 884   NaN
# 885   NaN
# 886   NaN
# 887   NaN
# 888   NaN
# 889   NaN
# 890   NaN
# 891   NaN
# 892   NaN
# 893   NaN
# 894   NaN
# 895   NaN
# 896   NaN
# 897   NaN
# 898   NaN
# Name: earlobe, Length: 617, dtype: float64
